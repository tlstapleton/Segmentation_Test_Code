# %%
import pandas as pd
import numpy as np
from scipy.optimize import minimize

# %%
hh="Python_HH_Demo_Data.csv"
hh_df = pd.read_csv(hh)
mk="MCCORMICK_ASSIGNMENT.csv"
mk_df = pd.read_csv(mk)

# %%
hh_df.head()
# Out:
#   MOSAIC_SEGMENT_ID Name            Value   Count
# 0               A01  AGE  HOH Age 19 - 25   56690
# 1               A01  AGE  HOH Age 26 - 35  272355
# 2               A01  AGE  HOH Age 36 - 45  244301
# 3               A01  AGE  HOH Age 46 - 55  595381
# 4               A01  AGE  HOH Age 56 - 65  530659

# %%
hh_df_new=pd.crosstab(hh_df["MOSAIC_SEGMENT_ID"],hh_df["Value"],values=hh_df["Count"],aggfunc=np.sum)
hh_df_new.head()
# Out:
# Value              1 Member HH  2 Member HH  3 Member HH  4 Member HH  \
# MOSAIC_SEGMENT_ID
# A01                   186658.0     592834.0     361185.0     327471.0
# A02                   192502.0     307736.0     188898.0     136836.0
# A03                     1093.0     121875.0     129444.0     139132.0
# A04                    10041.0     119219.0     141673.0     173179.0
# A05                   152312.0     639755.0     155378.0      52111.0
#
# Value              5+ Member HH  African American     Asian  Children Present  \
# MOSAIC_SEGMENT_ID
# A01                    512606.0           30839.0  247113.0          721791.0
# A02                    134943.0           31863.0   43087.0           79090.0
# A03                    295750.0           18726.0   85919.0          561770.0
# A04                    406588.0           31786.0   29422.0          704907.0
# A05                     35809.0           58505.0  145302.0          312698.0
#
# ...

# %%
mk_df.head()
# Out:
#    Unnamed: 0 Mosaic  Custom_seg      Prob
# 0           1    A06           2  0.386905
# 1           2    K39           2  0.379032
# 2           3    A05           2  0.350000
# 3           4    J35           3  0.346535
# 4           5    L43           3  0.328633

# %%
mk_df_new = mk_df.drop(['Unnamed: 0','Prob'],axis = 1)

# %%
mk_df_new_renamed=mk_df_new.rename(columns={"Mosaic":"MOSAIC_SEGMENT_ID"})
mk_df_new_renamed.head()
# Out:
#   MOSAIC_SEGMENT_ID  Custom_seg
# 0               A06           2
# 1               K39           2
# 2               A05           2
# 3               J35           3
# 4               L43           3

# %%
total_df=pd.merge(hh_df_new,mk_df_new_renamed,on = 'MOSAIC_SEGMENT_ID')

# %%
total_df.head()
# Out:
#   MOSAIC_SEGMENT_ID  1 Member HH  2 Member HH  3 Member HH  4 Member HH  \
# 0               A01     186658.0     592834.0     361185.0     327471.0
# 1               A02     192502.0     307736.0     188898.0     136836.0
# 2               A03       1093.0     121875.0     129444.0     139132.0
# 3               A04      10041.0     119219.0     141673.0     173179.0
# 4               A05     152312.0     639755.0     155378.0      52111.0
#
#    5+ Member HH  African American     Asian  Children Present  \
# 0      512606.0           30839.0  247113.0          721791.0
# 1      134943.0           31863.0   43087.0           79090.0
# 2      295750.0           18726.0   85919.0          561770.0
# 3      406588.0           31786.0   29422.0          704907.0
# 4       35809.0           58505.0  145302.0          312698.0
#
#    Completed College     ...      Income <$15,000    Married  \
# 0           592283.0     ...              15793.0  1933470.0
# ...

# %%
Seg_total_1=total_df.groupby("Custom_seg")["1 Member HH","2 Member HH","3 Member HH","4 Member HH","5+ Member HH"].sum()
print(Seg_total_1)
# Out:
#             1 Member HH  2 Member HH  3 Member HH  4 Member HH  5+ Member HH
# Custom_seg
# 1             5887704.0    7264630.0    1769406.0    1022800.0     1268260.0
# 2             9221257.0    9817557.0    4456676.0    2945954.0     3682544.0
# 3             9835545.0   10629709.0    4854753.0    2541915.0     2685733.0
# 4             2018836.0    6066565.0    2567031.0    2212400.0     3832285.0
# 5             7217600.0    9903760.0    2016488.0    1130369.0     1887247.0
# 6             2005983.0    1536395.0     586522.0     467795.0     1186311.0

# %%
custom_seg=Seg_total_1.sum(axis=1)
Seg_total_1['Segment_HH_Count']=Seg_total_1.sum(axis=1)
Seg_total_1
# Out:
#             1 Member HH  2 Member HH  3 Member HH  4 Member HH  5+ Member HH  \
# Custom_seg
# 1             5887704.0    7264630.0    1769406.0    1022800.0     1268260.0
# 2             9221257.0    9817557.0    4456676.0    2945954.0     3682544.0
# 3             9835545.0   10629709.0    4854753.0    2541915.0     2685733.0
# 4             2018836.0    6066565.0    2567031.0    2212400.0     3832285.0
# 5             7217600.0    9903760.0    2016488.0    1130369.0     1887247.0
# 6             2005983.0    1536395.0     586522.0     467795.0     1186311.0
#
#             Segment_HH_Count
# Custom_seg
# 1                 17212800.0
# 2                 30123988.0
# 3                 30547655.0
# 4                 16697117.0
# 5                 22155464.0
# 6                  5783006.0

# %%
totalhh=custom_seg.sum(axis=0)
totalhh
# Out:
# 122520030.0

# %%
Seg_total_1['Total_HH']=totalhh
Seg_total_1
# Out:
#             1 Member HH  2 Member HH  3 Member HH  4 Member HH  5+ Member HH  \
# Custom_seg
# 1             5887704.0    7264630.0    1769406.0    1022800.0     1268260.0
# 2             9221257.0    9817557.0    4456676.0    2945954.0     3682544.0
# 3             9835545.0   10629709.0    4854753.0    2541915.0     2685733.0
# 4             2018836.0    6066565.0    2567031.0    2212400.0     3832285.0
# 5             7217600.0    9903760.0    2016488.0    1130369.0     1887247.0
# 6             2005983.0    1536395.0     586522.0     467795.0     1186311.0
#
#             Segment_HH_Count     Total_HH
# Custom_seg
# 1                 17212800.0  122520030.0
# 2                 30123988.0  122520030.0
# 3                 30547655.0  122520030.0
# 4                 16697117.0  122520030.0
# 5                 22155464.0  122520030.0
# 6                  5783006.0  122520030.0

# %%
for column in Seg_total_1:
    Seg_total_1[f'Perc_{column}']=(Seg_total_1[column]/Seg_total_1['Segment_HH_Count'])*100
    
Seg_total_1
# Out:
#             1 Member HH  2 Member HH  3 Member HH  4 Member HH  5+ Member HH  \
# Custom_seg
# 1             5887704.0    7264630.0    1769406.0    1022800.0     1268260.0
# 2             9221257.0    9817557.0    4456676.0    2945954.0     3682544.0
# 3             9835545.0   10629709.0    4854753.0    2541915.0     2685733.0
# 4             2018836.0    6066565.0    2567031.0    2212400.0     3832285.0
# 5             7217600.0    9903760.0    2016488.0    1130369.0     1887247.0
# 6             2005983.0    1536395.0     586522.0     467795.0     1186311.0
#
#             Segment_HH_Count     Total_HH  Perc_1 Member HH  Perc_2 Member HH  \
# Custom_seg
# 1                 17212800.0  122520030.0         34.205382         42.204813
# 2                 30123988.0  122520030.0         30.611010         32.590496
# 3                 30547655.0  122520030.0         32.197381         34.797136
# 4                 16697117.0  122520030.0         12.090926         36.333009
# ...
